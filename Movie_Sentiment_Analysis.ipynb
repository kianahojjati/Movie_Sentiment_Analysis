# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/content/IMDB Dataset.csv")

# %%
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
data.tail()
# Out:
#                                                   review sentiment
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative

# %%
data.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
data.shape
# Out:
# (50000, 2)

# %%
data.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
data.isnull().any()
# Out:
# review       False
# sentiment    False
# dtype: bool

# %%
data['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
#tokenization
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
import spacy
import re,string,unicodedata
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer,WordNetLemmatizer
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from textblob import TextBlob
from textblob import Word
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from bs4 import BeautifulSoup

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#Tokenization of text
tokenizers=ToktokTokenizer()
#Setting English stopwords
stopwords=nltk.corpus.stopwords.words('english')

# %%
#Removing the noisy text
def noiseremoval_text(text):
  soup = BeautifulSoup(text, "html.parser")
  text = soup.get_text()
  text = re.sub('\[[^]]*\]', '', text)
  return text

# %%
#Apply function on review column
data['review']=data['review'].apply(noiseremoval_text)
# Out:
# <ipython-input-14-1065210c558d>:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")

# %%
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. The filming tec...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
#Stemming the text
def stemmer(text):
    ps=nltk.porter.PorterStemmer()
    text= ' '.join([ps.stem(word) for word in text.split()])
    return text

# %%
#Apply function on review column
data['review']=data['review'].apply(stemmer)

# %%
data.head()
# Out:
#                                               review sentiment
# 0  one of the other review ha mention that after ...  positive
# 1  a wonder littl production. the film techniqu i...  positive
# 2  i thought thi wa a wonder way to spend time on...  positive
# 3  basic there' a famili where a littl boy (jake)...  negative
# 4  petter mattei' "love in the time of money" is ...  positive

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
#set stopwords to english

stop_wr=set(stopwords.words('english'))
print(stop_wr)
# Out:
# {'for', 'doing', 'what', 'ain', 'my', 'against', 'now', 'them', 'they', 'just', 'other', 'further', "that'll", 'it', 'there', 'hasn', "should've", 'were', "wouldn't", 'wouldn', 'yourself', 'from', 'mustn', 'before', 'couldn', "shouldn't", 'will', 'hadn', 'until', 'as', "she's", 'again', 'll', 'weren', 'to', 'him', 'up', 'nor', 'needn', 'can', "aren't", 'below', 'those', 'all', 'd', 'ours', 'or', 'but', 'into', 'was', 're', 'haven', 'be', 'between', 'm', 'shan', 'a', 'under', 'then', 'these', 'yours', 'our', 'should', 'myself', 'your', "doesn't", 'with', "you'd", 've', "couldn't", "you'll", 'his', 'yourselves', 'having', "wasn't", 't', 'down', 'i', 'here', 'about', 'are', 'ourselves', 'where', 'you', 'both', 'y', 'each', 'don', 'he', "you're", 'the', 's', 'any', 'an', 'no', 'didn', 'after', 'which', 'at', 'if', 'more', 'am', "weren't", 'over', 'o', 'hers', 'being', 'me', 'during', "haven't", "shan't", 'mightn', 'when', 'only', 'whom', 'had', 'ma', 'off', 'very', 'out', 'so', 'on', 'su
# ...

# %%
#removing the stopwords
def removing_stopwords(text, is_lower_case=False):
    #Tokenization of text
    tokenizers=ToktokTokenizer()
    #Setting English stopwords
    tokens = tokenizers.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filter_tokens = [token for token in tokens if token not in stop_wr]
    else:
        filter_tokens = [token for token in tokens if token.lower() not in stop_wr]
    filtered_text = ' '.join(filter_tokens)
    return filtered_text

# %%
#Apply function on review column
data['review']=data['review'].apply(removing_stopwords)

# %%
data.head()
# Out:
#                                               review sentiment
# 0  one review ha mention watch 1 oz episod ' hook...  positive
# 1  wonder littl production. film techniqu veri un...  positive
# 2  thought thi wa wonder way spend time hot summe...  positive
# 3  basic ' famili littl boy ( jake ) think ' zomb...  negative
# 4  petter mattei ' " love time money " visual stu...  positive

# %%
#split the dataset
#train dataset
train_reviews_data=data.review[:30000]

# %%
#test dataset
test_reviews_data=data.review[30000:]

# %%
#Count vectorizer for bag of words
cv=CountVectorizer(min_df=1,max_df=1,binary=False,ngram_range=(1,3)) # Changed min_df to 1
#transformed train reviews
cv_train=cv.fit_transform(train_reviews_data)
#transformed test reviews
cv_test=cv.transform(test_reviews_data)

print('BOW_cv_train:',cv_train.shape)
print('BOW_cv_test:',cv_test.shape)
#vocab=cv.get_feature_names()-toget feature names
# Out:
# BOW_cv_train: (30000, 4954389)
# BOW_cv_test: (20000, 4954389)

# %%
#Tfidf vectorizer
tf=TfidfVectorizer(min_df=1,max_df=1.0,use_idf=True,ngram_range=(1,3)) # Changed min_df to 1
#transformed train reviews
tf_train=tf.fit_transform(train_reviews_data)
#transformed test reviews
tf_test=tf.transform(test_reviews_data)
print('Tfidf_train:',tf_train.shape)
print('Tfidf_test:',tf_test.shape)
# Out:
# Tfidf_train: (30000, 5543658)
# Tfidf_test: (20000, 5543658)

# %%
#labeling the sentient data
label=LabelBinarizer()
#transformed sentiment data
sentiment_data=label.fit_transform(data['sentiment'])
print(sentiment_data.shape)
# Out:
# (50000, 1)

# %%
train_data=data.sentiment[:30000]

# %%
test_data=data.sentiment[30000:]

# %%
#training the model
logistic=LogisticRegression(penalty='l2',max_iter=500,C=1,random_state=42)
#Fitting the model for Bag of words
lr_bow=logistic.fit(cv_train,train_data)
print(lr_bow)
#Fitting the model for tfidf features
lr_tfidf=logistic.fit(tf_train,train_data)
print(lr_tfidf)
# Out:
# LogisticRegression(C=1, max_iter=500, random_state=42)
# LogisticRegression(C=1, max_iter=500, random_state=42)

# %%
# Instead of fitting and transforming separately,
# fit on the entire dataset and then split

#Count vectorizer for bag of words
cv=CountVectorizer(min_df=1,max_df=1,binary=False,ngram_range=(1,3))

# Fit on the entire 'review' column
all_reviews_data = data['review']
cv_data = cv.fit_transform(all_reviews_data)

# Split the transformed data
cv_train = cv_data[:30000]
cv_test = cv_data[30000:]

print('BOW_cv_train:',cv_train.shape)
print('BOW_cv_test:',cv_test.shape)

# Repeat the same process for TfidfVectorizer
tf=TfidfVectorizer(min_df=1,max_df=1.0,use_idf=True,ngram_range=(1,3))
tf_data = tf.fit_transform(all_reviews_data)
tf_train = tf_data[:30000]
tf_test = tf_data[30000:]

print('Tfidf_train:',tf_train.shape)
print('Tfidf_test:',tf_test.shape)
# Out:
# BOW_cv_train: (30000, 7722805)
# BOW_cv_test: (20000, 7722805)
# Tfidf_train: (30000, 8733283)
# Tfidf_test: (20000, 8733283)

# %%
# Instead of fitting and transforming separately,
# fit on the entire dataset and then split

#Count vectorizer for bag of words
cv=CountVectorizer(min_df=1,max_df=1,binary=False,ngram_range=(1,3)) # You may want to adjust min_df and max_df

# Fit on the entire 'review' column
all_reviews_data = data['review']
cv_data = cv.fit_transform(all_reviews_data)

# Split the transformed data
cv_train = cv_data[:30000]
cv_test = cv_data[30000:]

print('BOW_cv_train:',cv_train.shape)
print('BOW_cv_test:',cv_test.shape)

# Repeat the same process for TfidfVectorizer
tf=TfidfVectorizer(min_df=1,max_df=1.0,use_idf=True,ngram_range=(1,3))  # You may want to adjust min_df and max_df
tf_data = tf.fit_transform(all_reviews_data)
tf_train = tf_data[:30000]
tf_test = tf_data[30000:]

print('Tfidf_train:',tf_train.shape)
print('Tfidf_test:',tf_test.shape)

#labeling the sentient data
label=LabelBinarizer()
#transformed sentiment data
sentiment_data=label.fit_transform(data['sentiment'])
print(sentiment_data.shape)

train_data=data.sentiment[:30000]
test_data=data.sentiment[30000:]

#training the model
logistic=LogisticRegression(penalty='l2',max_iter=500,C=1,random_state=42)

#Fitting the model for Bag of words
lr_bow=logistic.fit(cv_train,train_data) # Use cv_train from the consistent feature extraction
print(lr_bow)

#Fitting the model for tfidf features
lr_tfidf=logistic.fit(tf_train,train_data) # Use tf_train from the consistent feature extraction
print(lr_tfidf)

# Predicting the model for Bag of words
lr_bow_predict = lr_bow.predict(cv_test) # Use cv_test from the consistent feature extraction

#Accuracy score for bag of words
lr_bow_score=accuracy_score(test_data,lr_bow_predict)
print("lr_bow_score :",lr_bow_score)


##Predicting the model for tfidf features
lr_tfidf_predict=logistic.predict(tf_test) # Use tf_test from the consistent feature extraction


#Accuracy score for tfidf features
lr_tfidf_score=accuracy_score(test_data,lr_tfidf_predict)
print("lr_tfidf_score :",lr_tfidf_score)

# %%
#Accuracy score for bag of words
lr_bow_score=accuracy_score(test_data,lr_bow_predict)
print("lr_bow_score :",lr_bow_score)

# %%
#Accuracy score for tfidf features
lr_tfidf_score=accuracy_score(test_data,lr_tfidf_predict)
print("lr_tfidf_score :",lr_tfidf_score)
